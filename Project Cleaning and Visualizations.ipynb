# Vermont,7.5,1.6,8.6,1.6,8.7,1.9,8.1,1.2,8.6,1.4,8.3,1.1
# Virginia,9.8,1.6,7.8,1.4,8.8,1.5,8.8,1.2,8.3,1.1,8.8,1.1
# Washington,7.7,1.8,8.2,1.6,7.0,1.4,7.9,1.5,7.6,1.3,7.6,1.2
# West Virginia,16.9,2.1,14.2,3.0,13.9,1.9,15.5,2.3,14.0,1.7,15.0,1.6
# Wisconsin,9.3,1.9,8.0,1.8,8.4,1.6,8.7,1.5,8.2,1.4,8.6,1.3
# Wyoming,9.4,2.1,9.7,1.9,9.1,2.4,9.6,1.4,9.4,1.5,9.4,1.1
# Out:
# Overwriting state2.csv

# %%
import plotly.express as px
import pandas as pd
import csv
fruit_file = open('state2.csv')
fruit_data = list(csv.reader(fruit_file))
fruit_file.close()


df = pd.read_csv('state2.csv')
# df["year"] = [2019, 2020, 2021]
df.columns = ["state", "2021 percent", "2021 error", "2020 percent", "2020 error", "2019 percent", "2019 error", "2021-2020 percent", "2021-2020 error", "2020-2019 percent", "2020-2019 error", "2021-2019 percent", "2021-2019 error"]
df["code"] = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA','HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA','MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY','NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX','UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']
# print(df)

df2 = pd.DataFrame()
for index, row in df.iterrows():
  # df2.loc[len(df.index)] = [row["state"], 2019, row["2019 percent"]]
  # df2.loc[len(df.index)] = [row["state"], 2020, row["2020 percent"]]
  # df2.loc[len(df.index)] = [row["state"], 2021, row["2021 percent"]]
  df3 = {'state': row["state"], 'year': 2019, "percent": row["2019 percent"], "code":row["code"]}
  df2 = df2.append(df3, ignore_index = True)
  df3 = {'state': row["state"], 'year': 2020, "percent": row["2020 percent"], "code":row["code"]}
  df2 = df2.append(df3, ignore_index = True)
  df3 = {'state': row["state"], 'year': 2021, "percent": row["2021 percent"], "code":row["code"]}
  df2 = df2.append(df3, ignore_index = True)


print(df2)


# for i in range(len(fruit_data)):
#   for j in range(len(fruit_data[0])):
#     if j == 2:
#       fruit_data[i][j] = int(fruit_data[i][j])

# print(fruit_data)

# df = pd.DataFrame(fruit_data, columns=['Date', 'Fruit', 'Qty'])
# print(df)
# import plotly.graph_objects as go

# fig = go.Figure(go.Scattergeo())
# fig.update_geos(
#     visible=False, resolution=110, scope="usa",
#     showcountries=True, countrycolor="Black",
#     showsubunits=True, subunitcolor="Blue"
# )
# fig.update_layout(height=300, margin={"r":0,"t":0,"l":0,"b":0})

# fig = px.choropleth(df, locations='code', locationmode="USA-states", color='2021 percent', hover_name='state', animation_frame='2021 percent', scope = 'usa', labels={'2021 percent':'poverty'}, color_continuous_scale="Viridis")
fig = px.choropleth(df2, locations='code', locationmode="USA-states", color='percent', hover_name='state', animation_frame='year', scope = 'usa', labels={'percent':'poverty'}, color_continuous_scale="Viridis")

fig.show()
# Out:
# <ipython-input-26-cfc09eef1307>:21: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-26-cfc09eef1307>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-26-cfc09eef1307>:25: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-26-cfc09eef1307>:21: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-26-cfc09eef1307>:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-26-cfc09eef1307>:25: FutureWarning:
#
# ...

# %%
# creating an empty html file
fh = open('data_viz_full_embed.html', 'w')
fh.close()

import plotly.io as pio

pio.write_html(fig, file='data_viz_full_embed.html', auto_open=True, full_html=True) # create one html page with the viz embed

fh = open('data_viz_div_embed.html', 'w')
fh.close()

pio.write_html(fig, file='data_viz_div_embed.html', auto_open=True, full_html=False) # create one DIV only with the viz embed

# %%
from google.colab import drive

drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
path = "/content/drive/My Drive/EG Project/yearageraceCSV.csv"
df = pd.read_csv(path)
x = []
for i in range(1974, 2022):
  x.append(i)

# %%
xl = []
for i in range(1976, 2022):
  xl.append(i)
lkid = []
lmid = []
lold = []
for i in range(413, 461):
  if(pd.isna(df["Poor kid total"][i]) or int(df["Year"][i]) == 20172 or int(df["Year"][i]) == 20133):
    continue
  elif (df["Poor kid total"][i] == 'N'):
    lkid.append(0)
  elif (df["Poor middle total"][i] == 'N'):
    lmid.append(0)
  elif (df["Poor old total"][i] == 'N'):
    lold.append(0)
  else:
    lkid.append(float(df["Poor kid total"][i].replace(",", "")))
    lmid.append(float(df["Poor middle total"][i].replace(",", "")))
    lold.append(float(df["Poor old total"][i].replace(",", "")))

lkid.reverse()
lmid.reverse()
lold.reverse()
plt.title("Hispanic Age Groups in Poverty Over Time")
plt.xlabel("Year")
plt.ylabel("Amount of People")
plt.plot(xl, lkid, label = "<18 year olds", color = "g")
plt.plot(xl, lmid, label = "18-64 year olds", color = "b")
plt.plot(xl, lold, label = "65 year and older", color = "r")
plt.legend()
plt.show()

# %%
from matplotlib.pyplot import figure
import mpld3

fig = figure()
ax = fig.gca()
ax.plot([1,2,3,4])

mpld3.show(fig)

# %%
xa = []
for i in range(1987, 2022):
  xa.append(i)
akid = []
amid = []
aold = []
for i in range(289, 327):
  if(pd.isna(df["Poor kid total"][i]) or int(df["Year"][i]) == 20172 or int(df["Year"][i]) == 20133):
    continue
  elif (df["Poor kid total"][i] == 'N'):
    akid.append(0)
  elif (df["Poor middle total"][i] == 'N'):
    amid.append(0)
  elif (df["Poor old total"][i] == 'N'):
    aold.append(0)
  else:
    akid.append(float(df["Poor kid total"][i].replace(",", "")))
    amid.append(float(df["Poor middle total"][i].replace(",", "")))
    aold.append(float(df["Poor old total"][i].replace(",", "")))

akid.reverse()
amid.reverse()
aold.reverse()
plt.title("Asian Age Groups in Poverty Over Time")
plt.xlabel("Year")
plt.ylabel("Amount of People")
plt.plot(xa, akid, label = "<18 year olds", color = "g")
plt.plot(xa, amid, label = "18-64 year olds", color = "b")
plt.plot(xa, aold, label = "65 year and older", color = "r")
plt.legend()
plt.show()

# %%
nkid = []
nmid = []
nold = []
for i in range(351, 389):
  if(pd.isna(df["Poor kid total"][i]) or int(df["Year"][i]) == 20172 or int(df["Year"][i]) == 20133):
    continue
  elif (df["Poor kid total"][i] == 'N'):
    nkid.append(0)
  elif (df["Poor middle total"][i] == 'N'):
    nmid.append(0)
  elif (df["Poor old total"][i] == 'N'):
    nold.append(0)
  else:
    nkid.append(float(df["Poor kid total"][i].replace(",", "")))
    nmid.append(float(df["Poor middle total"][i].replace(",", "")))
    nold.append(float(df["Poor old total"][i].replace(",", "")))

nkid.reverse()
nmid.reverse()
nold.reverse()
plt.title("Native American and Alaskan Natives Age Groups in Poverty Over Time")
plt.xlabel("Year")
plt.ylabel("Amount of People")
plt.plot(xa, nkid, label = "<18 year olds", color = "g")
plt.plot(xa, nmid, label = "18-64 year olds", color = "b")
plt.plot(xa, nold, label = "65 year and older", color = "r")
plt.legend()
plt.show()

# %%
bkid = []
bmid = []
bold = []
for i in range(205, 256):
  if(pd.isna(df["Poor kid total"][i]) or int(df["Year"][i]) == 20172 or int(df["Year"][i]) == 20133):
    continue
  elif (df["Poor kid total"][i] == 'N'):
    bkid.append(0)
  elif (df["Poor middle total"][i] == 'N'):
    bmid.append(0)
  elif (df["Poor old total"][i] == 'N'):
    bold.append(0)
  else:
    bkid.append(float(df["Poor kid total"][i].replace(",", "")))
    bmid.append(float(df["Poor middle total"][i].replace(",", "")))
    bold.append(float(df["Poor old total"][i].replace(",", "")))

bkid.reverse()
bmid.reverse()
bold.reverse()
plt.title("African American Age Groups in Poverty Over Time")
plt.xlabel("Year")
plt.ylabel("Amount of People")
plt.plot(x, bkid, label = "<18 year olds", color = "g")
plt.plot(x, bmid, label = "18-64 year olds", color = "b")
plt.plot(x, bold, label = "65 year and older", color = "r")
plt.legend()
plt.show()

# %%
wkid = []
wmid = []
wold = []
for i in range(67, 118):
  if(pd.isna(df["Poor kid total"][i]) or int(df["Year"][i]) == 20172 or int(df["Year"][i]) == 20133):
    continue
  elif (df["Poor kid total"][i] == 'N'):
    wkid.append(0)
  elif (df["Poor middle total"][i] == 'N'):
    wmid.append(0)
  elif (df["Poor old total"][i] == 'N'):
    wold.append(0)
  else:
    wkid.append(float(df["Poor kid total"][i].replace(",", "")))
    wmid.append(float(df["Poor middle total"][i].replace(",", "")))
    wold.append(float(df["Poor old total"][i].replace(",", "")))

wkid.reverse()
wmid.reverse()
wold.reverse()
plt.title("White Age Groups in Poverty Over Time")
plt.xlabel("Year")
plt.ylabel("Amount of People")
plt.plot(x, wkid, label = "<18 year olds", color = "g")
plt.plot(x, wmid, label = "18-64 year olds", color = "b")
plt.plot(x, wold, label = "65 year and older", color = "r")
plt.legend()
plt.show()

# %%
import plotly.express as px
df2 = pd.DataFrame()
for i in range(1, 66):
  if(pd.isna(df["Poor kid total"][i]) or int(df["Year"][i]) == 20172 or int(df["Year"][i]) == 20133 or df["Poor middle total"][i] == 'N' or df["Poor kid total"][i] == 'N' or df["Poor old total"][i] == 'N'):
    continue
  else:
    df3 = {'year': int(str(df["Year"][i])[:4]), "age": "<18", "amount": float(df["Poor kid total"][i].replace(",", ""))}
    df2 = df2.append(df3, ignore_index = True)
    df3 = {'year': int(str(df["Year"][i])[:4]), "age": "18-64", "amount": float(df["Poor middle total"][i].replace(",", ""))}
    df2 = df2.append(df3, ignore_index = True)
    df3 = {'year': int(str(df["Year"][i])[:4]), "age": "65+", "amount": float(df["Poor old total"][i].replace(",", ""))}
    df2 = df2.append(df3, ignore_index = True)

fig = px.bar(df2, x = "age", y = "amount", color = "age", animation_frame = "year")
fig.show()

# kid = float(df["Poor kid total"][1].replace(",", ""))
# mid = float(df["Poor middle total"][1].replace(",", ""))
# old = float(df["Poor old total"][1].replace(",", ""))
# print(kid)

# pieData = [kid, mid, old]
# pieLabels = ["<18 Year Olds", "18-64 Year Olds", "65 and Older"]
# plt.pie(pieData, labels = pieLabels, startangle = 90, shadow = True)
# plt.title("Make up of Poor Population by Age Group, 2021")
# plt.show()
# Out:
# <ipython-input-39-c16b4b6f6824>:8: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-39-c16b4b6f6824>:10: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-39-c16b4b6f6824>:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-39-c16b4b6f6824>:8: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-39-c16b4b6f6824>:10: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-39-c16b4b6f6824>:12: FutureWarning:
#
# ...

# %%
# creating an empty html file
fh = open('2ages.html', 'w')
fh.close()

import plotly.io as pio

pio.write_html(fig, file='2ages.html', auto_open=True, full_html=True) # create one html page with the viz embed

fh = open('2ages.html', 'w')
fh.close()

pio.write_html(fig, file='2ages.html', auto_open=True, full_html=False) # create one DIV only with the viz embed

# %%
import pandas as pd
import matplotlib.pyplot as plt
path = "/content/drive/My Drive/EG Project/yearfamilyraceCSV2.csv"
df = pd.read_csv(path)
x = []
for i in range(1959, 2022):
  x.append(i)
whitePercent = []
blackPercent = []
asiaPercent = []
nativePercent = []
latinoPercent = []
allPercent = []

for i in range(1, 66):
  if(pd.isna(df["All poor total"][i]) or int(df["Year"][i]) == 20172 or int(df["Year"][i]) == 20133):
    continue
  else:
    allPercent.append(float(df["All poor total"][i].replace(",", "")) / float(df["All total"][i].replace(",", "")))

for i in range(67, 133):
  if(pd.isna(df["All poor total"][i])or int(df["Year"][i]) == 20172 or int(df["Year"][i]) == 20133):
    continue
  else:
    whitePercent.append(float(df["All poor total"][i].replace(",", "")) / float(df["All total"][i].replace(",", "")))

for i in range(210, 270):
  if(pd.isna(df["All poor total"][i])or int(df["Year"][i]) == 20172 or int(df["Year"][i]) == 20133):
    continue
  else:
    blackPercent.append(float(df["All poor total"][i].replace(",", "")) / float(df["All total"][i].replace(",", "")))

for i in range(294, 332):
  if(pd.isna(df["All poor total"][i])or int(df["Year"][i]) == 20172 or int(df["Year"][i]) == 20133):
    continue
  else:
    asiaPercent.append(float(df["All poor total"][i].replace(",", "")) / float(df["All total"][i].replace(",", "")))

for i in range(356, 394):
  if(pd.isna(df["All poor total"][i])or int(df["Year"][i]) == 20172 or int(df["Year"][i]) == 20133):
    continue
  else:
    nativePercent.append(float(df["All poor total"][i].replace(",", "")) / float(df["All total"][i].replace(",", "")))
  
for i in range(418, 470):
  if(pd.isna(df["All poor total"][i])or int(df["Year"][i]) == 20172 or int(df["Year"][i]) == 20133):
    continue
  else:
    latinoPercent.append(float(df["All poor total"][i].replace(",", "")) / float(df["All total"][i].replace(",", "")))

for i in range(28):
  # asiaPercent.append(0)
    asiaPercent.append(asiaPercent[34])
for i in range(28):
  # nativePercent.append(0)
    nativePercent.append(nativePercent[34])
for i in range(13):
  # latinoPercent.append(0)
    latinoPercent.append(latinoPercent[49])
for i in range(6):
  # blackPercent.append(0)
    blackPercent.append(blackPercent[56])

# print(len(nativePercent))
allPercent.reverse()
# print(len(blackPercent))
whitePercent.reverse()
blackPercent.reverse()
asiaPercent.reverse()
nativePercent.reverse()
latinoPercent.reverse()

# %%
print(float(df["All poor total"][1].replace(",", "")))
total = float(df["All poor total"][1].replace(",", ""))
white = float(df["All poor total"][67].replace(",", ""))
black = float(df["All poor total"][210].replace(",", ""))
asia = float(df["All poor total"][294].replace(",", ""))
native = float(df["All poor total"][356].replace(",", ""))
latino = float(df["All poor total"][418].replace(",", ""))
pieData = [white, black, asia, latino, native]
pieLabels = ["White", "African American", "Asian and Pacific Islander", "Hispanic", "Native American and Alaskan Native"]
plt.pie(pieData, labels = pieLabels, startangle = 90, shadow = True)
plt.title("Make up of Poor Population by Ethnicity, 2021")
plt.show()
# Out:
# 37933.0

# %%
plt.xlabel("Year")
plt.ylabel("Percent of population in poverty")
plt.title("Percentages of Population in Poverty Over Time")
plt.plot(x, allPercent, label = "all ethnicities")
plt.show()

plt.xlabel("Year")
plt.ylabel("Percent of population in poverty")
plt.title("Percentages of Different Ethnicities in Poverty Over Time")
plt.plot(x, whitePercent, label = "White", color = 'r')
plt.plot(x, blackPercent, label = "African American", color = 'b')
plt.plot(x, asiaPercent, label = "Asian and Pacific Islander", color = 'g')
plt.plot(x, nativePercent, label = "Native American and Alaskan Native", color = 'm')
plt.plot(x, latinoPercent, label = "Hispanic", color = 'y')
plt.legend()



plt.show()
